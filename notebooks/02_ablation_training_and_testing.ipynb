# %% [markdown]
# # Ablation models: training and testing
#
# Run notebook 01 first. Every reference/ablation model and seed has an independent cell with direct, unbuffered Python output.

# %%
# Mount Google Drive and install dependencies without retaining a pip cache.
from google.colab import drive
drive.mount('/content/drive')

PROJECT_DIR = '/content/drive/MyDrive/Dissertation/medical_vlm_fusion'
# %cd $PROJECT_DIR
# %pip -q install --no-cache-dir -r requirements.txt
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Dissertation/medical_vlm_fusion
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 314.7 MB/s eta 0:00:00

# %%
# Confirm the assigned GPU before starting ablation experiments.
# !nvidia-smi --query-gpu=name,memory.total --format=csv
# Out:
# name, memory.total [MiB]
# NVIDIA A100-SXM4-40GB, 40960 MiB

# %% [markdown]
# ## Seed 42

# %%
# Load/test the full bidirectional cross-attention reference with seed 42.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 42 --model bidirectional_cross_attention --action test

# %%
# Train and test bicross_i2t_only with seed 42.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 42 --model bicross_i2t_only --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1483566.97it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test bicross_t2i_only with seed 42.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 42 --model bicross_t2i_only --action train
# Out:
# ...
# 100% 13.2G/13.2G [10:35<00:00, 22.3MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/raddar/chest-xrays-indiana-university/versions/2
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1890283.61it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
# ...

# %%
# Train and test bicross_no_cross_attention with seed 42.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 42 --model bicross_no_cross_attention --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1702703.71it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test bicross_no_residual_update with seed 42.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 42 --model bicross_no_residual_update --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1347415.43it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test bicross_no_layer_norm with seed 42.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 42 --model bicross_no_layer_norm --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1719712.99it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test bicross_with_alignment_loss with seed 42.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 42 --model bicross_with_alignment_loss --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1678170.91it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %% [markdown]
# ## Seed 95

# %%
# Load/test the full bidirectional cross-attention reference with seed 95.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 95 --model bidirectional_cross_attention --action test

# %%
# Train and test bicross_i2t_only with seed 95.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 95 --model bicross_i2t_only --action test
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1688026.02it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test bicross_t2i_only with seed 95.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 95 --model bicross_t2i_only --action test
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1660560.25it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test bicross_no_cross_attention with seed 95.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 95 --model bicross_no_cross_attention --action test
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1585760.24it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test bicross_no_residual_update with seed 95.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 95 --model bicross_no_residual_update --action test
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1852287.96it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test bicross_no_layer_norm with seed 95.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 95 --model bicross_no_layer_norm --action test
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1293512.13it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test bicross_with_alignment_loss with seed 95.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 95 --model bicross_with_alignment_loss --action test
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1671367.27it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %% [markdown]
# ## Seed 1024

# %%
# Load/test the full bidirectional cross-attention reference with seed 1024.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 1024 --model bidirectional_cross_attention --action test

# %%
# Train and test bicross_i2t_only with seed 1024.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 1024 --model bicross_i2t_only --action test
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1712475.45it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test bicross_t2i_only with seed 1024.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 1024 --model bicross_t2i_only --action test
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1898415.59it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test bicross_no_cross_attention with seed 1024.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 1024 --model bicross_no_cross_attention --action test
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1710792.34it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test bicross_no_residual_update with seed 1024.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 1024 --model bicross_no_residual_update --action test
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1640561.89it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test bicross_no_layer_norm with seed 1024.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 1024 --model bicross_no_layer_norm --action test
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1699840.00it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test bicross_with_alignment_loss with seed 1024.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/ablation_experiment.py" --seed 1024 --model bicross_with_alignment_loss --action test
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1723781.41it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...
