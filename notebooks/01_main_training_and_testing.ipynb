# %% [markdown]
# # Main models: preprocessing, training, and testing
#
# Run from top to bottom in Colab. Preprocessing and every model/seed combination have independent cells with direct, unbuffered Python output.

# %%
# Mount Google Drive and install dependencies without retaining a pip cache.
from google.colab import drive
drive.mount('/content/drive')

PROJECT_DIR = '/content/drive/MyDrive/Dissertation/medical_vlm_fusion'
# %cd $PROJECT_DIR
# %pip -q install --no-cache-dir -r requirements.txt
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Dissertation/medical_vlm_fusion
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 276.7 MB/s eta 0:00:00

# %%
# Confirm the assigned GPU before starting preprocessing and experiments.
# !nvidia-smi --query-gpu=name,memory.total --format=csv
# Out:
# name, memory.total [MiB]
# NVIDIA A100-SXM4-40GB, 40960 MiB

# %% [markdown]
# ## Preprocessing

# %%
# Generate the IU X-ray CheXpert-14 processed files in project artifacts/data.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/preprocessing/preprocess_iu_xray_chexpert14.py"
# Out:
# Google Drive mount failed. If you are not in Colab, this is expected.
# Reason: AttributeError("'NoneType' object has no attribute 'kernel'")
# SAVE_DIR: /content/drive/MyDrive/Dissertation/medical_vlm_fusion/artifacts/data/iu_xray_chexpert14
# RAW_OUTPUT_CSV: /content/drive/MyDrive/Dissertation/medical_vlm_fusion/artifacts/data/iu_xray_chexpert14/iu_xray_chexpert14_raw.csv
# BINARY_OUTPUT_CSV: /content/drive/MyDrive/Dissertation/medical_vlm_fusion/artifacts/data/iu_xray_chexpert14/iu_xray_chexpert14_binary_u_zero.csv
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# reports_csv: /kaggle/input/chest-xrays-indiana-university/indiana_reports.csv
# projections_csv: /kaggle/input/chest-xrays-indiana-university/indiana_projections.csv
# num image files found: 7470
# reports_df shape: (3851, 8)
# proj_df shape: (7466, 3)
# ...

# %% [markdown]
# ## Seed 42

# %%
# Train and test image_only with seed 42.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 42 --model image_only --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1765052.72it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test text_only with seed 42.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 42 --model text_only --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1656521.67it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test concat_fusion with seed 42.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 42 --model concat_fusion --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1687026.22it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test average_fusion with seed 42.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 42 --model average_fusion --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1659592.72it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test gated_fusion with seed 42.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 42 --model gated_fusion --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1726345.85it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test self_attention_fusion with seed 42.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 42 --model self_attention_fusion --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1620704.06it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test bidirectional_cross_attention with seed 42.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 42 --model bidirectional_cross_attention --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1690120.34it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %% [markdown]
# ## Seed 95

# %%
# Train and test image_only with seed 95.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 95 --model image_only --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1681774.07it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test text_only with seed 95.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 95 --model text_only --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1666300.64it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test concat_fusion with seed 95.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 95 --model concat_fusion --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1734277.14it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test average_fusion with seed 95.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 95 --model average_fusion --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1534125.78it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test gated_fusion with seed 95.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 95 --model gated_fusion --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1665680.54it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test self_attention_fusion with seed 95.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 95 --model self_attention_fusion --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1617107.14it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test bidirectional_cross_attention with seed 95.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 95 --model bidirectional_cross_attention --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1678170.91it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %% [markdown]
# ## Seed 1024

# %%
# Train and test image_only with seed 1024.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 1024 --model image_only --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1684305.50it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test text_only with seed 1024.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 1024 --model text_only --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1714818.61it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test concat_fusion with seed 1024.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 1024 --model concat_fusion --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1693225.84it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test average_fusion with seed 1024.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 1024 --model average_fusion --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1657748.72it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test gated_fusion with seed 1024.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 1024 --model gated_fusion --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1673152.35it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test self_attention_fusion with seed 1024.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 1024 --model self_attention_fusion --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1650500.49it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...

# %%
# Train and test bidirectional_cross_attention with seed 1024.
# !python -u "/content/drive/MyDrive/Dissertation/medical_vlm_fusion/src/main_experiment.py" --seed 1024 --model bidirectional_cross_attention --action train
# Out:
# Using Colab cache for faster access to the 'chest-xrays-indiana-university' dataset.
# Path to dataset files: /kaggle/input/chest-xrays-indiana-university
# Indexing image files: 100% 7470/7470 [00:00<00:00, 1633037.16it/s]
# Final df shape: (3666, 28)
#                             positive_count
# No Finding                           917.0
# Lung Lesion                          465.0
# Lung Opacity                         365.0
# Atelectasis                          303.0
# Support Devices                      258.0
# Cardiomegaly                         240.0
# Pleural Effusion                     199.0
# Pneumonia                             97.0
# Fracture                              92.0
# Edema                                 78.0
# Pneumothorax                          67.0
# Pleural Other                         37.0
# Consolidation                         33.0
# Enlarged Cardiomediastinum             8.0
#    uid                   filename  ... Fracture Support Devices
# ...
